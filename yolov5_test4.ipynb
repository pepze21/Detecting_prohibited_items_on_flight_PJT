# %%
from glob import glob
import yaml
from IPython.display import Image
import os

# %%
img_list = glob('/home/ubuntu/dataset/images/*.jpg')
print(len(img_list))
# Out:
# 364

# %%
from sklearn.model_selection import train_test_split
train_img_list, val_img_list = train_test_split(img_list, test_size=0.3, random_state=0)

print(len(train_img_list), len(val_img_list))
# Out:
# 254 110

# %%
with open('/home/ubuntu/dataset/train.txt', 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')
    
with open('/home/ubuntu/dataset/val.txt', 'w') as f:
    f.write('\n'.join(val_img_list) + '\n')

# %%
with open('/home/ubuntu/dataset/data.yaml', 'r', encoding='utf-8') as f:
    data = yaml.load(f, Loader=yaml.FullLoader)
    
print(data)
# Out:
# {'download': 'https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip', 'names': ['knife'], 'nc': 2, 'path': '../datasets/coco128', 'test': None, 'train': '/home/ubuntu/dataset/train.txt', 'val': '/home/ubuntu/dataset/val.txt'}

# %%
data['train'] = '/home/ubuntu/dataset/train.txt'
data['val'] = '/home/ubuntu/dataset/val.txt'
data['nc'] = 1
data['names'] = ['knife']

with open('/home/ubuntu/dataset/data.yaml', 'w') as f:
    yaml.dump(data, f)

print(data)
# Out:
# {'download': 'https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip', 'names': ['knife'], 'nc': 1, 'path': '../datasets/coco128', 'test': None, 'train': '/home/ubuntu/dataset/train.txt', 'val': '/home/ubuntu/dataset/val.txt'}

# %%
# %pwd
# Out:
# '/home/ubuntu/workspace'

# %%
# %cd ..
# Out:
# /home/ubuntu

# %%
# %cd yolov5
# Out:
# /home/ubuntu/yolov5

# %%
# %%time
# !python train.py --img 512 --batch 16 --epochs 4000 --data /home/ubuntu/dataset/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name prohibited_items_on_board
# Out:
# wandb: Currently logged in as: pepze21 (use `wandb login --relogin` to force relogin)
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/home/ubuntu/dataset/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=4000, batch_size=16, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=prohibited_items_on_board, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 7 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# %%time
# !python train.py --img 512 --batch 16 --epochs 4000 --data /home/ubuntu/dataset/data.yaml --cfg ./models/yolov5m.yaml --weights yolov5m.pt --name prohibited_items_on_board_m
# Out:
# wandb: Currently logged in as: pepze21 (use `wandb login --relogin` to force relogin)
# train: weights=yolov5m.pt, cfg=./models/yolov5m.yaml, data=/home/ubuntu/dataset/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=4000, batch_size=16, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=prohibited_items_on_board_m, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 7 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
#시작 11:05

# %%
# %load_ext tensorboard
# %tensorboard --logdir /home/ubuntu/yolov5/runs/

# %%
val_img_path = val_img_list[0]
# !python detect.py --weights /home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt --img 384 --conf 0.5 --source "{val_img_path}"
# Out:
# detect: weights=['/home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt'], source=/home/ubuntu/dataset/images/230.jpg, imgsz=[384, 384], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %%
val_img_path = val_img_list[1]
# !python detect.py --weights /home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt --img 384 --conf 0.5 --source "{val_img_path}"
# Out:
# detect: weights=['/home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt'], source=/home/ubuntu/dataset/images/344.jpg, imgsz=[384, 384], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %%
val_img_path = val_img_list[2]
# !python detect.py --weights /home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt --img 384 --conf 0.5 --source "{val_img_path}"
# Out:
# detect: weights=['/home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt'], source=/home/ubuntu/dataset/images/118.jpg, imgsz=[384, 384], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %%
val_img_path = val_img_list[3]
# !python detect.py --weights /home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt --img 384 --conf 0.5 --source "{val_img_path}"
# Out:
# detect: weights=['/home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt'], source=/home/ubuntu/dataset/images/136.jpg, imgsz=[384, 384], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %%
val_img_path = val_img_list[4]
# !python detect.py --weights /home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt --img 384 --conf 0.5 --source "{val_img_path}"
# Out:
# detect: weights=['/home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt'], source=/home/ubuntu/dataset/images/70.jpg, imgsz=[384, 384], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %%
val_img_path = val_img_list[5]
# !python detect.py --weights /home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt --img 384 --conf 0.5 --source "{val_img_path}"
# Out:
# detect: weights=['/home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt'], source=/home/ubuntu/dataset/images/296.jpg, imgsz=[384, 384], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %%
val_img_path = val_img_list[6]
# !python detect.py --weights /home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt --img 384 --conf 0.5 --source "{val_img_path}"
# Out:
# detect: weights=['/home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt'], source=/home/ubuntu/dataset/images/204.jpg, imgsz=[384, 384], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %%
val_img_path = val_img_list[7]
# !python detect.py --weights /home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt --img 384 --conf 0.5 --source "{val_img_path}"
# Out:
# detect: weights=['/home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt'], source=/home/ubuntu/dataset/images/380.jpg, imgsz=[384, 384], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %%
val_img_path = val_img_list[8]
# !python detect.py --weights /home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt --img 384 --conf 0.5 --source "{val_img_path}"
# Out:
# detect: weights=['/home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt'], source=/home/ubuntu/dataset/images/311.jpg, imgsz=[384, 384], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %%
val_img_path = val_img_list[9]
# !python detect.py --weights /home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt --img 384 --conf 0.5 --source "{val_img_path}"
# Out:
# detect: weights=['/home/ubuntu/yolov5/runs/train/prohibited_items_on_board/weights/best.pt'], source=/home/ubuntu/dataset/images/198.jpg, imgsz=[384, 384], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %% [markdown]
# ![n](/home/ubuntu/yolov5/runs/train/prohibited_items_on_board/results.png)

# %%
# Image("/home/ubuntu/yolov5/runs/train/prohibited_items_on_board/train_batch0.jpg")
