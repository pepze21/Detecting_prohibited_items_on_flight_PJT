# %%
from glob import glob
import yaml
import os
from IPython.display import Image
import matplotlib.image as img
import matplotlib.pyplot as plt

# %%
test_img_list = glob('/home/ubuntu/dataset/test/images/*.jpg')
print(len(test_img_list))
# Out:
# 192

# %%
with open('/home/ubuntu/dataset/test.txt', 'w') as f:
    f.write('\n'.join(test_img_list) + '\n')

with open('/home/ubuntu/dataset/data_test.yaml', 'r', encoding='utf-8') as f:
    data = yaml.load(f, Loader=yaml.FullLoader)

data['test'] = '/home/ubuntu/dataset/test.txt'
data['nc'] = 5
data['names'] = ['knife', 'spray', 'portable_charger', 'lighter', 'e_cigarette']

with open('/home/ubuntu/dataset/data_test.yaml', 'w') as f:
    yaml.dump(data, f)

print(data)
# Out:
# {'download': 'https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip', 'names': ['knife', 'spray', 'portable_charger', 'lighter', 'e_cigarette'], 'nc': 5, 'path': '../datasets/coco128', 'test': '/home/ubuntu/dataset/test.txt', 'train': '/home/ubuntu/dataset/train.txt', 'val': '/home/ubuntu/dataset/val.txt'}

# %%
# %pwd
# Out:
# '/home/ubuntu/yolov5'

# %%
# %cd ..
# Out:
# /home/ubuntu

# %%
# %cd yolov5
# Out:
# /home/ubuntu/yolov5

# %% [markdown]
# ### yolov5s test model

# %%
# %%time
# !python test.py --img 384 --data /home/ubuntu/dataset/data_test.yaml --weights /home/ubuntu/yolov5/best_s944.pt --task 'test'
# Out:
# test: data=/home/ubuntu/dataset/data_test.yaml, weights=['/home/ubuntu/yolov5/best_s944.pt'], batch_size=32, imgsz=384, conf_thres=0.001, iou_thres=0.6, task=test, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 v6.0-55-g0155548 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning '/home/ubuntu/dataset/test.cache' images and labels... 192 found,
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        192        352      0.693      0.609      0.663      0.496
#                knife        192         63      0.609      0.666      0.621      0.385
#                spray        192         42      0.953      0.667      0.811      0.694
# ...

# %%
Image('/home/ubuntu/yolov5/runs/val/exp/F1_curve.png')

# %%
Image('/home/ubuntu/yolov5/runs/val/exp/PR_curve.png')

# %%
Image('/home/ubuntu/yolov5/runs/val/exp/P_curve.png')

# %%
Image('/home/ubuntu/yolov5/runs/val/exp/R_curve.png')

# %%
Image('/home/ubuntu/yolov5/runs/val/exp/confusion_matrix.png')

# %%
Image('/home/ubuntu/yolov5/runs/val/exp/val_batch0_labels.jpg')

# %%
Image('/home/ubuntu/yolov5/runs/val/exp/val_batch0_pred.jpg')

# %%
Image('/home/ubuntu/yolov5/runs/val/exp/val_batch1_labels.jpg')

# %%
Image('/home/ubuntu/yolov5/runs/val/exp/val_batch1_pred.jpg')

# %%
Image('/home/ubuntu/yolov5/runs/val/exp/val_batch2_labels.jpg')

# %%
Image('/home/ubuntu/yolov5/runs/val/exp/val_batch2_pred.jpg')
