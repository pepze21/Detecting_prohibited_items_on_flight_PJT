# %%
from glob import glob
import yaml
import os
from IPython.display import Image
import matplotlib.image as img
import matplotlib.pyplot as plt

# %%
# %pwd
# Out:
# '/home/ubuntu/workspace'

# %%
# %cd ..
# Out:
# /home/ubuntu

# %%
# %cd yolov5
# Out:
# /home/ubuntu/yolov5

# %% [markdown]
# ### Detect (Inference)
# .jpg 파일의 detect 결과는 home/ubuntu/yolov5/runs/detect/exp 폴더에 .jpg 형태로 저장됨

# %%
# !python detect_customized_v1.py --weights /home/ubuntu/yolov5/runs/train/prohibited_items_on_board_s6/weights/best.pt --img 608 --conf 0.5 --source /home/ubuntu/yolov5/data/images/KakaoTalk_20211112_170828797_01.jpg
# Out:
# detect_customized_v1: weights=['/home/ubuntu/yolov5/runs/train/prohibited_items_on_board_s6/weights/best.pt'], source=/home/ubuntu/yolov5/data/images/KakaoTalk_20211112_170828797_01.jpg, imgsz=[608, 608], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-55-g0155548 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# Traceback (most recent call last):
#   File "detect_customized_v1.py", line 330, in <module>
#     main(opt)
#   File "detect_customized_v1.py", line 325, in main
#     run(**vars(opt))
# ...

# %%
# !python detect.py --weights /home/ubuntu/yolov5/runs/train/prohibited_items_on_board_s6/weights/best.pt --img 608 --conf 0.1 --source /home/ubuntu/yolov5/data/images/KakaoTalk_20211112_170828797_01.jpg
# Out:
# detect: weights=['/home/ubuntu/yolov5/runs/train/prohibited_items_on_board_s6/weights/best.pt'], source=/home/ubuntu/yolov5/data/images/KakaoTalk_20211112_170828797_01.jpg, imgsz=[608, 608], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-55-g0155548 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /home/ubuntu/yolov5/data/images/KakaoTalk_20211112_170828797_01.jpg: 608x480 3 knifes, Done. (0.012s)
# Speed: 0.5ms pre-process, 11.8ms inference, 1.2ms NMS per image at shape (1, 3, 608, 608)
# Results saved to runs/detect/exp12

# %%
# !python detect.py --weights /home/ubuntu/yolov5/runs/train/prohibited_items_on_board_s6/weights/best.pt --img 608 --conf 0.1 --source /home/ubuntu/yolov5/data/images/KakaoTalk_20211112_170828797_02.jpg
# Out:
# detect: weights=['/home/ubuntu/yolov5/runs/train/prohibited_items_on_board_s6/weights/best.pt'], source=/home/ubuntu/yolov5/data/images/KakaoTalk_20211112_170828797_02.jpg, imgsz=[608, 608], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-55-g0155548 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /home/ubuntu/yolov5/data/images/KakaoTalk_20211112_170828797_02.jpg: 576x608 1 knife, Done. (0.014s)
# Speed: 0.5ms pre-process, 14.4ms inference, 1.2ms NMS per image at shape (1, 3, 608, 608)
# Results saved to runs/detect/exp13

# %%
# !python detect.py --weights /home/ubuntu/yolov5/runs/train/prohibited_items_on_board_s6/weights/best.pt --img 608 --conf 0.1 --source /home/ubuntu/yolov5/data/images/KakaoTalk_20211112_170828797_03.jpg
# Out:
# detect: weights=['/home/ubuntu/yolov5/runs/train/prohibited_items_on_board_s6/weights/best.pt'], source=/home/ubuntu/yolov5/data/images/KakaoTalk_20211112_170828797_03.jpg, imgsz=[608, 608], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-55-g0155548 torch 1.10.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /home/ubuntu/yolov5/data/images/KakaoTalk_20211112_170828797_03.jpg: 608x480 2 knifes, 1 portable_charger, Done. (0.012s)
# Speed: 0.5ms pre-process, 11.8ms inference, 1.2ms NMS per image at shape (1, 3, 608, 608)
# Results saved to runs/detect/exp14

# %%
Image('/home/ubuntu/yolov5/runs/detect/exp12/KakaoTalk_20211112_170828797_01.jpg')

# %%
Image('/home/ubuntu/yolov5/runs/detect/exp13/KakaoTalk_20211112_170828797_02.jpg')

# %%
Image('/home/ubuntu/yolov5/runs/detect/exp14/KakaoTalk_20211112_170828797_03.jpg')
